# %% [markdown]
# Importing original dataset in and dropping only the first column

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Read in newly cleaned data from data_visualization.pynb
original_data = pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
balanced_data = original_data.dropna()

balanced_data = balanced_data.drop(columns= "id")

balanced_data = balanced_data[balanced_data.age > 20]

balanced_data = balanced_data.drop(balanced_data.index[balanced_data["gender"] == "Other"])

from sklearn.preprocessing import OneHotEncoder, StandardScaler
features = ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', "bmi", "smoking_status"]
cat_columns = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
num_columns = ['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi']

from imblearn.pipeline import Pipeline as imb_pipeline
from sklearn.pipeline import Pipeline as pipeline
from imblearn.over_sampling import SMOTENC
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier

num_pipeline = imb_pipeline([
    ("scale", StandardScaler())
])

one_hot_pipeline = imb_pipeline([
    ("one hot encode", OneHotEncoder(sparse_output = False))
])

preprocessing = ColumnTransformer([
    ("numeric", num_pipeline, num_columns),
    ("one-Hot", one_hot_pipeline, cat_columns),
])

combined_pipeline = imb_pipeline(steps= [
        ("smotenc", SMOTENC(cat_columns, random_state = 1)),
        ('preprocessing', preprocessing),
       ])

# %% [markdown]
# Pycaret auto machine learning test

# %%
from pycaret.classification import setup, compare_models, evaluate_model, predict_model

#Design my own pipeline for pycaret to test
setup(original_data, 
      target='stroke', 
      train_size = 0.8,
)
# Out:
# <style type="text/css">
# #T_c5397_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c5397">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5397_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c5397_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5397_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5397_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c5397_row0_col1" class="data row0 col1" >5059</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5397_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c5397_row1_col1" class="data row1 col1" >stroke</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5397_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c5397_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c5397_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c5397_row3_col1" class="data row3 col1" >(5110, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c5397_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c5397_row4_col1" class="data row4 col1" >(5110, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c5397_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c5397_row5_col1" class="data row5 col1" >(4088, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c5397_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c5397_row6_col1" class="data row6 col1" >(1022, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c5397_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_c5397_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c5397_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_c5397_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c5397_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_c5397_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c5397_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_c5397_row10_col1" class="data row10 col1" >3.9%</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c5397_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_c5397_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c5397_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_c5397_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c5397_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_c5397_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c5397_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_c5397_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c5397_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_c5397_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c5397_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_c5397_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c5397_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_c5397_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c5397_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_c5397_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c5397_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_c5397_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c5397_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_c5397_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c5397_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_c5397_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c5397_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_c5397_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c5397_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c5397_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_c5397_row23_col1" class="data row23 col1" >a38e</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models(sort= "Recall")
# Out:
# <style type="text/css">
# #T_08fbc th {
#   text-align: left;
# }
# #T_08fbc_row0_col0, #T_08fbc_row0_col1, #T_08fbc_row0_col2, #T_08fbc_row0_col4, #T_08fbc_row0_col5, #T_08fbc_row0_col6, #T_08fbc_row0_col7, #T_08fbc_row1_col0, #T_08fbc_row1_col1, #T_08fbc_row1_col2, #T_08fbc_row1_col3, #T_08fbc_row1_col4, #T_08fbc_row2_col0, #T_08fbc_row2_col1, #T_08fbc_row2_col2, #T_08fbc_row2_col3, #T_08fbc_row2_col4, #T_08fbc_row2_col5, #T_08fbc_row2_col6, #T_08fbc_row2_col7, #T_08fbc_row3_col0, #T_08fbc_row3_col1, #T_08fbc_row3_col2, #T_08fbc_row3_col3, #T_08fbc_row3_col4, #T_08fbc_row3_col5, #T_08fbc_row3_col6, #T_08fbc_row3_col7, #T_08fbc_row4_col0, #T_08fbc_row4_col1, #T_08fbc_row4_col2, #T_08fbc_row4_col3, #T_08fbc_row4_col5, #T_08fbc_row4_col6, #T_08fbc_row4_col7, #T_08fbc_row5_col0, #T_08fbc_row5_col1, #T_08fbc_row5_col2, #T_08fbc_row5_col3, #T_08fbc_row5_col4, #T_08fbc_row5_col5, #T_08fbc_row5_col6, #T_08fbc_row5_col7, #T_08fbc_row6_col0, #T_08fbc_row6_col1, #T_08fbc_row6_col3, #T_08fbc_row6_col4, #T_08fbc_row6_col5, #T_08fbc_row6_col6, #T_08fbc_row6_col7, #T_08fbc_row7_col0, #T_08fbc_row7_col1, #T_08fbc_row7_col2, #T_08fbc_row7_col3, #T_08fbc_row7_col4, #T_08fbc_row7_col5, #T_08fbc_row7_col6, #T_08fbc_row7_col7, #T_08fbc_row8_col0, #T_08fbc_row8_col1, #T_08fbc_row8_col2, #T_08fbc_row8_col3, #T_08fbc_row8_col4, #T_08fbc_row8_col5, #T_08fbc_row8_col6, #T_08fbc_row8_col7, #T_08fbc_row9_col0, #T_08fbc_row9_col1, #T_08fbc_row9_col2, #T_08fbc_row9_col3, #T_08fbc_row9_col4, #T_08fbc_row9_col5, #T_08fbc_row9_col6, #T_08fbc_row9_col7, #T_08fbc_row10_col0, #T_08fbc_row10_col1, #T_08fbc_row10_col2, #T_08fbc_row10_col3, #T_08fbc_row10_col4, #T_08fbc_row10_col5, #T_08fbc_row10_col6, #T_08fbc_row10_col7, #T_08fbc_row11_col0, #T_08fbc_row11_col2, #T_08fbc_row11_col3, #T_08fbc_row11_col4, #T_08fbc_row11_col5, #T_08fbc_row11_col6, #T_08fbc_row11_col7, #T_08fbc_row12_col0, #T_08fbc_row12_col1, #T_08fbc_row12_col2, #T_08fbc_row12_col3, #T_08fbc_row12_col4, #T_08fbc_row12_col5, #T_08fbc_row12_col6, #T_08fbc_row12_col7, #T_08fbc_row13_col0, #T_08fbc_row13_col2, #T_08fbc_row13_col3, #T_08fbc_row13_col4, #T_08fbc_row13_col5, #T_08fbc_row13_col6, #T_08fbc_row13_col7 {
#   text-align: left;
# }
# #T_08fbc_row0_col3, #T_08fbc_row1_col5, #T_08fbc_row1_col6, #T_08fbc_row1_col7, #T_08fbc_row4_col4, #T_08fbc_row6_col2, #T_08fbc_row11_col1, #T_08fbc_row13_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_08fbc_row0_col8, #T_08fbc_row1_col8, #T_08fbc_row2_col8, #T_08fbc_row3_col8, #T_08fbc_row4_col8, #T_08fbc_row5_col8, #T_08fbc_row6_col8, #T_08fbc_row7_col8, #T_08fbc_row8_col8, #T_08fbc_row9_col8, #T_08fbc_row10_col8, #T_08fbc_row12_col8, #T_08fbc_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_08fbc_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_08fbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08fbc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_08fbc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_08fbc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_08fbc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_08fbc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_08fbc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_08fbc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_08fbc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_08fbc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08fbc_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_08fbc_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_08fbc_row0_col1" class="data row0 col1" >0.5432</td>
#       <td id="T_08fbc_row0_col2" class="data row0 col2" >0.5957</td>
#       <td id="T_08fbc_row0_col3" class="data row0 col3" >0.6287</td>
#       <td id="T_08fbc_row0_col4" class="data row0 col4" >0.0647</td>
#       <td id="T_08fbc_row0_col5" class="data row0 col5" >0.1145</td>
#       <td id="T_08fbc_row0_col6" class="data row0 col6" >0.0382</td>
#       <td id="T_08fbc_row0_col7" class="data row0 col7" >0.0782</td>
#       <td id="T_08fbc_row0_col8" class="data row0 col8" >0.1070</td>
#     </tr>
#     <tr>
#       <th id="T_08fbc_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_08fbc_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_08fbc_row1_col1" class="data row1 col1" >0.9156</td>
#       <td id="T_08fbc_row1_col2" class="data row1 col2" >0.8175</td>
#       <td id="T_08fbc_row1_col3" class="data row1 col3" >0.2068</td>
#       <td id="T_08fbc_row1_col4" class="data row1 col4" >0.1760</td>
#       <td id="T_08fbc_row1_col5" class="data row1 col5" >0.1883</td>
#       <td id="T_08fbc_row1_col6" class="data row1 col6" >0.1443</td>
#       <td id="T_08fbc_row1_col7" class="data row1 col7" >0.1458</td>
#       <td id="T_08fbc_row1_col8" class="data row1 col8" >0.1200</td>
#     </tr>
#     <tr>
#       <th id="T_08fbc_level0_row2" class="row_heading level0 row2" >svm</th>
#       <td id="T_08fbc_row2_col0" class="data row2 col0" >SVM - Linear Kernel</td>
#       <td id="T_08fbc_row2_col1" class="data row2 col1" >0.8575</td>
#       <td id="T_08fbc_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_08fbc_row2_col3" class="data row2 col3" >0.1103</td>
#       <td id="T_08fbc_row2_col4" class="data row2 col4" >0.0549</td>
#       <td id="T_08fbc_row2_col5" class="data row2 col5" >0.0264</td>
#       <td id="T_08fbc_row2_col6" class="data row2 col6" >0.0092</td>
#       <td id="T_08fbc_row2_col7" class="data row2 col7" >0.0107</td>
#       <td id="T_08fbc_row2_col8" class="data row2 col8" >0.1290</td>
#     </tr>
#     <tr>
#       <th id="T_08fbc_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_08fbc_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_08fbc_row3_col1" class="data row3 col1" >0.9078</td>
#       <td id="T_08fbc_row3_col2" class="data row3 col2" >0.5174</td>
#       <td id="T_08fbc_row3_col3" class="data row3 col3" >0.0850</td>
#       <td id="T_08fbc_row3_col4" class="data row3 col4" >0.0777</td>
#       <td id="T_08fbc_row3_col5" class="data row3 col5" >0.0806</td>
#       <td id="T_08fbc_row3_col6" class="data row3 col6" >0.0325</td>
#       <td id="T_08fbc_row3_col7" class="data row3 col7" >0.0326</td>
#       <td id="T_08fbc_row3_col8" class="data row3 col8" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_08fbc_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_08fbc_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_08fbc_row4_col1" class="data row4 col1" >0.9469</td>
#       <td id="T_08fbc_row4_col2" class="data row4 col2" >0.8243</td>
#       <td id="T_08fbc_row4_col3" class="data row4 col3" >0.0553</td>
#       <td id="T_08fbc_row4_col4" class="data row4 col4" >0.2817</td>
#       <td id="T_08fbc_row4_col5" class="data row4 col5" >0.0911</td>
#       <td id="T_08fbc_row4_col6" class="data row4 col6" >0.0765</td>
#       <td id="T_08fbc_row4_col7" class="data row4 col7" >0.1049</td>
#       <td id="T_08fbc_row4_col8" class="data row4 col8" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_08fbc_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_08fbc_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_08fbc_row5_col1" class="data row5 col1" >0.9462</td>
#       <td id="T_08fbc_row5_col2" class="data row5 col2" >0.8060</td>
#       <td id="T_08fbc_row5_col3" class="data row5 col3" >0.0353</td>
#       <td id="T_08fbc_row5_col4" class="data row5 col4" >0.1786</td>
#       <td id="T_08fbc_row5_col5" class="data row5 col5" >0.0573</td>
#       <td id="T_08fbc_row5_col6" class="data row5 col6" >0.0440</td>
#       <td id="T_08fbc_row5_col7" class="data row5 col7" >0.0594</td>
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)
